# %%
import mysql.connector
from dotenv import load_dotenv
import os

load_dotenv()

db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_host = os.getenv("DB_HOST")
print(db_host)
# MariaDB 연결 설정
config = {
    'user': db_user,
    'password': db_password,
    'host': db_host,
    "port": 3306,
    "database": "S09P22A301",  
}

# MariaDB 연결
connection = mysql.connector.connect(**config)

# SQL 쿼리 실행
cursor = connection.cursor()
cursor.execute('SHOW TABLES;')

tables = cursor.fetchall()
# 테이블 목록 출력
print(len(tables))
for table in tables:
    print(table[0]+"\n")

# 연결 종료
cursor.close()
connection.close()
# Out:
# stg-yswa-kr-practice-db-master.mariadb.database.azure.com
# 18
# fielding
#
# fielding_seq
#
# hitting
#
# hitting_seq
#
# match_detail
#
# matches
#
# pitching
#
# pitching_seq
#
# player
#
# player_like
#
# player_like_seq
#
# season_roster
#
# team
#
# team_like
#
# team_like_seq
#
# team_stat
#
# team_stat_seq
#
# users

# %%
create_player_table= "CREATE TABLE player (\
    player_id BIGINT PRIMARY KEY,\
    name VARCHAR(255) NOT NULL,\
    kor_name VARCHAR(255),\
    is_playing TINYINT(1) NOT NULL,\
    height INT,\
    weight INT,\
    main_position ENUM(\
        'PITCHER', 'CATCHER', 'FIRST_BASEMAN', 'SECOND_BASEMAN',\
        'THIRD_BASEMAN', 'SHORTSTOP', 'LEFT_FIELDER', 'CENTER_FIELDER',\
        'RIGHT_FIELDER', 'DESIGNATED_HITTER', 'PINCH_HITTER',\
        'PINCH_RUNNER', 'EXTRA_HITTER', 'BASE_RUNNER', 'OUTFIELD',\
        'INFIELD', 'STARTING_PITCHER', 'RELIEF_PITCHER', 'CLOSER',\
        'UTILITY', 'UTILITY_INFIELDER', 'UTILITY_OUTFIELDER',\
        'RIGHT_HANDED_PITCHER', 'LEFT_HANDED_PITCHER',\
        'RIGHT_HANDED_STARTER', 'LEFT_HANDED_STARTER',\
        'LEFT_HANDED_RELIEVER', 'RIGHT_HANDED_RELIEVER',\
        'PITCHER_INFIELDER', 'PITCHER_OUTFIELDER', 'PITCHER_UTILITY',\
        'TWO_WAY_PLAYER', 'BATTER', 'RUNNER_ON_FIRST',\
        'RUNNER_ON_SECOND', 'RUNNER_ON_THIRD'\
    ) NOT NULL,\
    main_hand ENUM('LEFT', 'RIGHT', 'BOTH') NOT NULL,\
    image VARCHAR(255),\
    debut_date DATETIME,\
    retire_date DATETIME,\
    hometown VARCHAR(255),\
    backnumber INT\
);"

create_fielding_table = "CREATE TABLE fielding (\
    fielding_stat_id BIGINT AUTO_INCREMENT PRIMARY KEY,\
    player_id BIGINT,\
    season INT,\
    error INT,\
    assist INT,\
    putout INT,\
    games_played INT,\
    position ENUM('PITCHER', 'CATCHER', 'FIRST_BASEMAN', 'SECOND_BASEMAN',\
                  'THIRD_BASEMAN', 'SHORTSTOP', 'LEFT_FIELDER', 'CENTER_FIELDER',\
                  'RIGHT_FIELDER', 'DESIGNATED_HITTER', 'PINCH_HITTER',\
                  'PINCH_RUNNER', 'EXTRA_HITTER', 'BASE_RUNNER', 'OUTFIELD',\
                  'INFIELD', 'STARTING_PITCHER', 'RELIEF_PITCHER', 'CLOSER',\
                  'UTILITY', 'UTILITY_INFIELDER', 'UTILITY_OUTFIELDER',\
                  'RIGHT_HANDED_PITCHER', 'LEFT_HANDED_PITCHER',\
                  'RIGHT_HANDED_STARTER', 'LEFT_HANDED_STARTER',\
                  'LEFT_HANDED_RELIEVER', 'RIGHT_HANDED_RELIEVER',\
                  'PITCHER_INFIELDER', 'PITCHER_OUTFIELDER', 'PITCHER_UTILITY',\
                  'TWO_WAY_PLAYER', 'BATTER', 'RUNNER_ON_FIRST',\
                  'RUNNER_ON_SECOND', 'RUNNER_ON_THIRD'),\
    FOREIGN KEY (player_id) REFERENCES player (player_id)\
);"

create_hitting_table = "CREATE TABLE hitting (\
    hitting_stat_id BIGINT AUTO_INCREMENT PRIMARY KEY,\
    player_id BIGINT,\
    season INT,\
    games_played INT,\
    batting_avg FLOAT,\
    slugging_avg FLOAT,\
    obp FLOAT,\
    hits INT,\
    runs INT,\
    rbi INT,\
    homerun INT,\
    stolenbases INT,\
    ops FLOAT,\
    wrc FLOAT,\
    war FLOAT,\
    at_bats INT,\
    FOREIGN KEY (player_id) REFERENCES player (player_id)\
);"

create_pitching_table = "CREATE TABLE pitching (\
    pitching_stat_id BIGINT AUTO_INCREMENT PRIMARY KEY,\
    player_id BIGINT,\
    season INT,\
    games_played INT,\
    innings_played FLOAT,\
    win INT,\
    lose INT,\
    era FLOAT,\
    save INT,\
    whip FLOAT,\
    kbb FLOAT,\
    blown_save INT,\
    FOREIGN KEY (player_id) REFERENCES player (player_id)\
);"

create_match_table = "CREATE TABLE `match` (\
    match_id BIGINT PRIMARY KEY,\
    home_id BIGINT,\
    away_id BIGINT,\
    home_pitcher VARCHAR(255),\
    away_pitcher VARCHAR(255),\
    match_date DATETIME,\
    home_score INT,\
    away_score INT,\
    home_name VARCHAR(255),\
    away_name VARCHAR(255),\
    status VARCHAR(255),\
    current_inning INT,\
    match_detail_id BIGINT,\
    FOREIGN KEY (home_id) REFERENCES team (team_id),\
    FOREIGN KEY (away_id) REFERENCES team (team_id),\
    FOREIGN KEY (match_detail_id) REFERENCES match_detail (match_detail_id)\
);"

create_match_detail_table = "CREATE TABLE match_detail (\
    match_detail_id BIGINT PRIMARY KEY,\
    linescore TEXT,\
    boxscore TEXT,\
);"

create_team_table = "CREATE TABLE team (\
    team_id BIGINT PRIMARY KEY,\
    team_name VARCHAR(255),\
    created_date DATETIME,\
    team_logo VARCHAR(255),\
    team_location VARCHAR(255)\
);"

create_team_stat_table="CREATE TABLE team_stat (\
    teamstat_id BIGINT AUTO_INCREMENT PRIMARY KEY,\
    team_id BIGINT,\
    season INT,\
    win_percentage FLOAT,\
    win INT,\
    lose INT,\
    draw INT,\
    batting_avg FLOAT,\
    era_avg FLOAT,\
    division_rank INT,\
    league_rank INT,\
    FOREIGN KEY (team_id) REFERENCES team (team_id)\
);"

create_season_roster_table = "CREATE TABLE season_roster (\
    sr_id BIGINT AUTO_INCREMENT PRIMARY KEY,\
    player_id BIGINT,\
    team_id BIGINT,\
    season INT,\
    FOREIGN KEY (player_id) REFERENCES player (player_id),\
    FOREIGN KEY (team_id) REFERENCES team (team_id)\
);"

# %%
import mysql.connector

# 연결 설정
# config = {
#     'user': db_user,
#     'password': db_password,
#     'host': db_host,
#     "port": 3306,
#     "database": "S09P22A301",  
# }

# 연결 설정
config = {
    "user": "S09P22A301@stg-yswa-kr-practice-db-master.mariadb.database.azure.com",                 # 사용자 이름
    "password": "QmK0nwCJzS",             # 비밀번호
    "host": "stg-yswa-kr-practice-db-master.mariadb.database.azure.com",  # 호스트 이름 또는 IP 주소
    "port": 3306,                            # 포트 번호 (기본값은 3306)
    "database": "S09P22A301",               # 데이터베이스 이름
}


# 연결 생성
connection = mysql.connector.connect(**config)

# 커서 생성
cursor = connection.cursor()

#table 생성


# cursor.execute("DROP TABLE if exists fielding;")
# #cursor.execute(create_fielding_table)

# cursor.execute("DROP TABLE if exists hitting;")
# #cursor.execute(create_hitting_table)

# cursor.execute("DROP TABLE if exists pitching;")
# #cursor.execute(create_pitching_table)

# cursor.execute("DROP TABLE if exists `match` CASCADE;")
# #cursor.execute(create_match_table)

# cursor.execute("DROP TABLE if exists match_detail;")
# #cursor.execute(create_match_detail_table)

# cursor.execute("DROP TABLE if exists team;")
# #cursor.execute(create_team_table)

# cursor.execute("DROP TABLE if exists team_stat;")
# #cursor.execute(create_team_stat_table)

# cursor.execute("DROP TABLE if exists season_roster;")
# #cursor.execute(create_season_roster_table)

# cursor.execute("DROP TABLE if exists player;")
# #cursor.execute(create_player_table)

cursor.execute('SHOW TABLES;')
tables = cursor.fetchall()

# 테이블 목록 출력
print(len(tables))
for table in tables:
    print(table[0]+"\n")

# 연결 종료
cursor.close()
connection.close()
# Out:
# 17
# fielding
#
# fielding_seq
#
# hitting
#
# hitting_seq
#
# match_detail
#
# pitching
#
# pitching_seq
#
# player
#
# player_like
#
# player_like_seq
#
# season_roster
#
# team
#
# team_like
#
# team_like_seq
#
# team_stat
#
# team_stat_seq
#
# users

# %%
def parse_height(height_str):
    if height_str == None:
        return -1
    # 문자열을 공백으로 분할하여 피트와 인치를 추출
    parts = height_str.split()
    
    feet = 0
    inches = 0
    
    # '피트'를 찾아 변환
    if "'" in parts[0]:
        feet = int(parts[0].replace("'", ""))
    
    # '인치'를 찾아 변환
    if len(parts) > 1 and '"' in parts[1]:
        inches = int(parts[1].replace('"', ''))
    
    # 피트와 인치를 센티미터로 변환
    feet_to_cm = feet * 30.48
    inches_to_cm = inches * 2.54
    
    # 센티미터로 전체 높이 계산
    height_cm = feet_to_cm + inches_to_cm
    
    return height_cm

# %%
import mysql.connector
from dotenv import load_dotenv
import os

load_dotenv()

db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_host = os.getenv("DB_HOST")
print(db_host)
# MariaDB 연결 설정
config = {
    'user': db_user,
    'password': db_password,
    'host': db_host,
    "port": 3306,
    "database": "S09P22A301",  
}

# 연결 생성
connection = mysql.connector.connect(**config)

# 커서 생성
cursor = connection.cursor()

folder_path = 'players_stat'
for filename in os.listdir(folder_path):
    if filename.endswith('.json'):
        try:
            with open(os.path.join(folder_path, filename), 'r') as json_file:
                data = json.load(json_file)
                player_id = data.get("id")
                # print(player_id)
                name = data.get("fullName")
                is_playing = data.get("active")
                height = parse_height(data.get("height"))
                if(data.get("weight") != None):
                    weight = data.get("weight")
                else:
                    weight = -1
                main_position = data.get("primaryPosition").get("name").upper()
                main_position = main_position.replace(" ", "_")
                main_position = main_position.replace("-", "_")
                if(data.get("pitchHand") != None):
                    main_hand = data.get("pitchHand").get("description").upper()
                else:
                    main_hand = None

                if data.get("mlbDebutDate") != None:  
                    debut_date = datetime.strptime(data.get("mlbDebutDate"),"%Y-%m-%d")
                else:
                    debut_date = None
                if(data.get("lastPlayedDate") != None):
                    retire_date = datetime.strptime(data.get("lastPlayedDate"),"%Y-%m-%d")
                else:
                    retire_date = None
                hometown = data.get("birthCity")
                if(data.get("primaryNumber")!= None):
                    backnumber = data.get("primaryNumber")
                else:
                    backnumber = -1
                # 데이터베이스에 데이터 삽입
                cursor.execute('''
                    INSERT INTO `player` (player_id, name, is_playing, height, weight, main_position, main_hand, debut_date, retire_date, hometown, backnumber)
                    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                ''', (player_id, name, is_playing, height, weight, main_position, main_hand, debut_date, retire_date, hometown, backnumber))
                connection.commit()
        except mysql.connector.IntegrityError as e :
            continue
        except Exception as e2:
            print(f"{filename} 에러 발생: {str(e2)}")

# 연결 종료
cursor.close()
connection.close()
# Out:
# stg-yswa-kr-practice-db-master.mariadb.database.azure.com
# players_stat_121600.json 에러 발생: name 'date' is not defined
# players_stat_124185.json 에러 발생: name 'date' is not defined
# players_stat_113333.json 에러 발생: name 'date' is not defined
# players_stat_123510.json 에러 발생: name 'date' is not defined
# players_stat_113961.json 에러 발생: name 'date' is not defined
# players_stat_122823.json 에러 발생: name 'date' is not defined
# players_stat_502582.json 에러 발생: name 'date' is not defined
# players_stat_455759.json 에러 발생: name 'date' is not defined
# players_stat_113617.json 에러 발생: name 'date' is not defined
# players_stat_425548.json 에러 발생: name 'date' is not defined
# players_stat_114389.json 에러 발생: name 'date' is not defined
# players_stat_114834.json 에러 발생: name 'date' is not defined
# players_stat_150302.json 에러 발생: name 'date' is not defined
# players_stat_112371.json 에러 발생: name 'date' is not defined
# players_stat_122844.json 에러 발생: name 'date' is not defined
# players_stat_123123.json 에러 발생: name 'date' is not defined
# players_stat_491688.json 에러 발생: name 'date' is not defined
# players_stat_124236.json 에러 발생: name 'date' is not defined
# players_stat_113779.json 에러 발생: name 'date' is not defined
# players_stat_117579.json 에러 발생: name 'date' is not defined
# players_stat_656495.json 에러 발생: name 'date' is not defined
# players_stat_116929.json 에러 발생: name 'date' is not defined
# players_stat_113527.json 에러 발생: name 'date' is not defined
# players_stat_110043.json 에러 발생: name 'date' is not defined
# players_stat_120731.json 에러 발생: name 'date' is not defined
# players_stat_112882.json 에러 발생: name 'date' is not defined
# players_stat_118923.json 에러 발생: name 'date' is not defined
# players_stat_111551.json 에러 발생: name 'date' is not defined
# players_stat_110046.json 에러 발생: name 'date' is not defined
# players_stat_112303.json 에러 발생: name 'date' is not defined
# players_stat_643290.json 에러 발생: name 'date' is not defined
# players_stat_150023.json 에러 발생: name 'date' is not defined
# players_stat_124533.json 에러 발생: name 'date' is not defined
# players_stat_115340.json 에러 발생: name 'date' is not defined
# players_stat_123981.json 에러 발생: name 'date' is not defined
# players_stat_110180.json 에러 발생: name 'date' is not defined
# players_stat_608422.json 에러 발생: name 'date' is not defined
# players_stat_111062.json 에러 발생: name 'date' is not defined
# players_stat_123473.json 에러 발생: name 'date' is not defined
# players_stat_123666.json 에러 발생: name 'date' is not defined
# players_stat_118487.json 에러 발생: name 'date' is not defined
# players_stat_116704.json 에러 발생: name 'date' is not defined
# players_stat_112057.json 에러 발생: name 'date' is not defined
# players_stat_407932.json 에러 발생: name 'date' is not defined
# players_stat_124732.json 에러 발생: name 'date' is not defined
# players_stat_118787.json 에러 발생: name 'date' is not defined
# players_stat_542883.json 에러 발생: name 'date' is not defined
# players_stat_110677.json 에러 발생: name 'date' is not defined
# players_stat_110420.json 에러 발생: name 'date' is not defined
# players_stat_114571.json 에러 발생: name 'date' is not defined
# players_stat_122644.json 에러 발생: name 'date' is not defined
# players_stat_117344.json 에러 발생: name 'date' is not defined
# players_stat_114902.json 에러 발생: name 'date' is not defined
# players_stat_122733.json 에러 발생: name 'date' is not defined
# players_stat_115668.json 에러 발생: name 'date' is not defined
# players_stat_111919.json 에러 발생: name 'date' is not defined
# players_stat_112579.json 에러 발생: name 'date' is not defined
# players_stat_116855.json 에러 발생: name 'date' is not defined
# players_stat_668968.json 에러 발생: name 'date' is not defined
# players_stat_116935.json 에러 발생: name 'date' is not defined
# players_stat_121301.json 에러 발생: name 'date' is not defined
# players_stat_123758.json 에러 발생: name 'date' is not defined
# players_stat_117145.json 에러 발생: name 'date' is not defined
# players_stat_605439.json 에러 발생: name 'date' is not defined
# players_stat_117073.json 에러 발생: name 'date' is not defined
# players_stat_136861.json 에러 발생: name 'date' is not defined
# players_stat_117257.json 에러 발생: name 'date' is not defined
# players_stat_117534.json 에러 발생: name 'date' is not defined
# players_stat_150053.json 에러 발생: name 'date' is not defined
# players_stat_115556.json 에러 발생: name 'date' is not defined
# players_stat_150311.json 에러 발생: name 'date' is not defined
# players_stat_543079.json 에러 발생: name 'date' is not defined
# players_stat_113125.json 에러 발생: name 'date' is not defined
# players_stat_115755.json 에러 발생: name 'date' is not defined
# players_stat_452217.json 에러 발생: name 'date' is not defined
# players_stat_446290.json 에러 발생: name 'date' is not defined
# players_stat_665154.json 에러 발생: name 'date' is not defined
# players_stat_285068.json 에러 발생: name 'date' is not defined
# players_stat_518595.json 에러 발생: name 'date' is not defined
# players_stat_150420.json 에러 발생: name 'date' is not defined
# players_stat_110442.json 에러 발생: name 'date' is not defined
# players_stat_115976.json 에러 발생: name 'date' is not defined
# players_stat_110970.json 에러 발생: name 'date' is not defined
# players_stat_682989.json 에러 발생: name 'date' is not defined
# players_stat_118122.json 에러 발생: name 'date' is not defined
# players_stat_110549.json 에러 발생: name 'date' is not defined
# players_stat_115634.json 에러 발생: name 'date' is not defined
# players_stat_110652.json 에러 발생: name 'date' is not defined
# players_stat_118677.json 에러 발생: name 'date' is not defined
# players_stat_122066.json 에러 발생: name 'date' is not defined
# players_stat_110477.json 에러 발생: name 'date' is not defined
# players_stat_545338.json 에러 발생: name 'date' is not defined
# players_stat_681432.json 에러 발생: name 'date' is not defined
# players_stat_425531.json 에러 발생: name 'date' is not defined
# players_stat_460104.json 에러 발생: name 'date' is not defined
# players_stat_116026.json 에러 발생: name 'date' is not defined
# players_stat_668970.json 에러 발생: name 'date' is not defined
# players_stat_122510.json 에러 발생: name 'date' is not defined
# players_stat_114574.json 에러 발생: name 'date' is not defined
# players_stat_110139.json 에러 발생: name 'date' is not defined
# players_stat_518626.json 에러 발생: name 'date' is not defined
# players_stat_122220.json 에러 발생: name 'date' is not defined
# players_stat_115382.json 에러 발생: name 'date' is not defined
# players_stat_571761.json 에러 발생: name 'date' is not defined
# players_stat_456665.json 에러 발생: name 'date' is not defined
# players_stat_118870.json 에러 발생: name 'date' is not defined
# players_stat_110273.json 에러 발생: name 'date' is not defined
# players_stat_124513.json 에러 발생: name 'date' is not defined
# players_stat_116206.json 에러 발생: name 'date' is not defined
# players_stat_119598.json 에러 발생: name 'date' is not defined
# players_stat_120583.json 에러 발생: name 'date' is not defined
# players_stat_123679.json 에러 발생: name 'date' is not defined
# players_stat_115335.json 에러 발생: name 'date' is not defined
# players_stat_121309.json 에러 발생: name 'date' is not defined
# players_stat_119058.json 에러 발생: name 'date' is not defined
# players_stat_607951.json 에러 발생: name 'date' is not defined
# players_stat_120820.json 에러 발생: name 'date' is not defined
# players_stat_113437.json 에러 발생: name 'date' is not defined
# players_stat_121922.json 에러 발생: name 'date' is not defined
# players_stat_123094.json 에러 발생: name 'date' is not defined
# players_stat_124737.json 에러 발생: name 'date' is not defined
# players_stat_120554.json 에러 발생: name 'date' is not defined
# players_stat_116563.json 에러 발생: name 'date' is not defined
# players_stat_114308.json 에러 발생: name 'date' is not defined
# players_stat_122527.json 에러 발생: name 'date' is not defined
# players_stat_115375.json 에러 발생: name 'date' is not defined
# players_stat_119994.json 에러 발생: name 'date' is not defined
# players_stat_451257.json 에러 발생: name 'date' is not defined
# players_stat_122492.json 에러 발생: name 'date' is not defined
# players_stat_425126.json 에러 발생: name 'date' is not defined
# players_stat_122605.json 에러 발생: name 'date' is not defined
# players_stat_664875.json 에러 발생: name 'date' is not defined
# players_stat_648737.json 에러 발생: name 'date' is not defined
# players_stat_643550.json 에러 발생: name 'date' is not defined
# players_stat_452293.json 에러 발생: name 'date' is not defined
# players_stat_113460.json 에러 발생: name 'date' is not defined
# players_stat_123005.json 에러 발생: name 'date' is not defined
# players_stat_119651.json 에러 발생: name 'date' is not defined
# players_stat_110322.json 에러 발생: name 'date' is not defined
# players_stat_122431.json 에러 발생: name 'date' is not defined
# players_stat_113114.json 에러 발생: name 'date' is not defined
# players_stat_672730.json 에러 발생: name 'date' is not defined
# players_stat_669276.json 에러 발생: name 'date' is not defined
# players_stat_123148.json 에러 발생: name 'date' is not defined
# players_stat_117948.json 에러 발생: name 'date' is not defined
# players_stat_111821.json 에러 발생: name 'date' is not defined
# players_stat_114277.json 에러 발생: name 'date' is not defined
# players_stat_571862.json 에러 발생: name 'date' is not defined
# players_stat_650859.json 에러 발생: name 'date' is not defined
# players_stat_571697.json 에러 발생: name 'date' is not defined
# players_stat_116785.json 에러 발생: name 'date' is not defined
# players_stat_451585.json 에러 발생: name 'date' is not defined
# players_stat_115642.json 에러 발생: name 'date' is not defined
# players_stat_691587.json 에러 발생: name 'date' is not defined
# players_stat_657557.json 에러 발생: name 'date' is not defined
# players_stat_118072.json 에러 발생: name 'date' is not defined
# players_stat_446213.json 에러 발생: name 'date' is not defined
# players_stat_118324.json 에러 발생: name 'date' is not defined
# players_stat_113376.json 에러 발생: name 'date' is not defined
# players_stat_460004.json 에러 발생: name 'date' is not defined
# players_stat_111029.json 에러 발생: name 'date' is not defined
# players_stat_114339.json 에러 발생: name 'date' is not defined
# players_stat_114954.json 에러 발생: name 'date' is not defined
# players_stat_501817.json 에러 발생: name 'date' is not defined
# players_stat_282565.json 에러 발생: name 'date' is not defined
# players_stat_120917.json 에러 발생: name 'date' is not defined
# players_stat_119893.json 에러 발생: name 'date' is not defined
# players_stat_122398.json 에러 발생: name 'date' is not defined
# players_stat_571476.json 에러 발생: name 'date' is not defined
# players_stat_663534.json 에러 발생: name 'date' is not defined
# players_stat_113780.json 에러 발생: name 'date' is not defined
# players_stat_122177.json 에러 발생: name 'date' is not defined
# players_stat_123567.json 에러 발생: name 'date' is not defined
# players_stat_118665.json 에러 발생: name 'date' is not defined
# players_stat_400309.json 에러 발생: name 'date' is not defined
# players_stat_124528.json 에러 발생: name 'date' is not defined
# players_stat_592609.json 에러 발생: name 'date' is not defined
# players_stat_121412.json 에러 발생: name 'date' is not defined
# players_stat_543184.json 에러 발생: name 'date' is not defined
# players_stat_117866.json 에러 발생: name 'date' is not defined
# players_stat_111913.json 에러 발생: name 'date' is not defined
# players_stat_122182.json 에러 발생: name 'date' is not defined
# players_stat_112790.json 에러 발생: name 'date' is not defined
# players_stat_115170.json 에러 발생: name 'date' is not defined
# players_stat_117697.json 에러 발생: name 'date' is not defined
# players_stat_113603.json 에러 발생: name 'date' is not defined
# players_stat_113589.json 에러 발생: name 'date' is not defined
# players_stat_407482.json 에러 발생: name 'date' is not defined
# players_stat_641796.json 에러 발생: name 'date' is not defined
# players_stat_117943.json 에러 발생: name 'date' is not defined
# players_stat_119627.json 에러 발생: name 'date' is not defined
# players_stat_124548.json 에러 발생: name 'date' is not defined
# players_stat_118806.json 에러 발생: name 'date' is not defined
# players_stat_117187.json 에러 발생: name 'date' is not defined
# players_stat_122982.json 에러 발생: name 'date' is not defined
# players_stat_121431.json 에러 발생: name 'date' is not defined
# players_stat_124154.json 에러 발생: name 'date' is not defined
# players_stat_120288.json 에러 발생: name 'date' is not defined
# players_stat_150392.json 에러 발생: name 'date' is not defined
# players_stat_116578.json 에러 발생: name 'date' is not defined
# players_stat_120221.json 에러 발생: name 'date' is not defined
# players_stat_116161.json 에러 발생: name 'date' is not defined
# players_stat_124555.json 에러 발생: name 'date' is not defined
# players_stat_110132.json 에러 발생: name 'date' is not defined
# players_stat_120854.json 에러 발생: name 'date' is not defined
# players_stat_124480.json 에러 발생: name 'date' is not defined
# players_stat_121241.json 에러 발생: name 'date' is not defined
# players_stat_119056.json 에러 발생: name 'date' is not defined
# players_stat_121386.json 에러 발생: name 'date' is not defined
# players_stat_686759.json 에러 발생: name 'date' is not defined
# players_stat_111141.json 에러 발생: name 'date' is not defined
# players_stat_111665.json 에러 발생: name 'date' is not defined
# players_stat_434671.json 에러 발생: name 'date' is not defined
# players_stat_425833.json 에러 발생: name 'date' is not defined
# players_stat_119693.json 에러 발생: name 'date' is not defined
# players_stat_117093.json 에러 발생: name 'date' is not defined
# players_stat_112661.json 에러 발생: name 'date' is not defined
# players_stat_113505.json 에러 발생: name 'date' is not defined
# players_stat_115349.json 에러 발생: name 'date' is not defined
# players_stat_607369.json 에러 발생: name 'date' is not defined
# players_stat_114100.json 에러 발생: name 'date' is not defined
# players_stat_676702.json 에러 발생: name 'date' is not defined
# players_stat_120771.json 에러 발생: name 'date' is not defined
# players_stat_118889.json 에러 발생: name 'date' is not defined
# players_stat_123907.json 에러 발생: name 'date' is not defined
# players_stat_456124.json 에러 발생: name 'date' is not defined
# players_stat_113014.json 에러 발생: name 'date' is not defined
# players_stat_121631.json 에러 발생: name 'date' is not defined
# players_stat_445971.json 에러 발생: name 'date' is not defined
# players_stat_120700.json 에러 발생: name 'date' is not defined
# players_stat_122636.json 에러 발생: name 'date' is not defined
# players_stat_122741.json 에러 발생: name 'date' is not defined
# players_stat_116028.json 에러 발생: name 'date' is not defined
# players_stat_112981.json 에러 발생: name 'date' is not defined
# players_stat_117911.json 에러 발생: name 'date' is not defined
# players_stat_650339.json 에러 발생: name 'date' is not defined
# players_stat_122797.json 에러 발생: name 'date' is not defined
# players_stat_123541.json 에러 발생: name 'date' is not defined
# players_stat_123028.json 에러 발생: name 'date' is not defined
# players_stat_111009.json 에러 발생: name 'date' is not defined
# players_stat_119525.json 에러 발생: name 'date' is not defined
# players_stat_572119.json 에러 발생: name 'date' is not defined
# players_stat_111686.json 에러 발생: name 'date' is not defined
# players_stat_122702.json 에러 발생: name 'date' is not defined
# players_stat_115782.json 에러 발생: name 'date' is not defined
# players_stat_122223.json 에러 발생: name 'date' is not defined
# players_stat_120314.json 에러 발생: name 'date' is not defined
# players_stat_666674.json 에러 발생: name 'date' is not defined
# players_stat_111883.json 에러 발생: name 'date' is not defined
# players_stat_112977.json 에러 발생: name 'date' is not defined
# players_stat_657277.json 에러 발생: name 'date' is not defined
# players_stat_112944.json 에러 발생: name 'date' is not defined
# players_stat_117621.json 에러 발생: name 'date' is not defined
# players_stat_453232.json 에러 발생: name 'date' is not defined
# players_stat_124223.json 에러 발생: name 'date' is not defined
# players_stat_117466.json 에러 발생: name 'date' is not defined
# players_stat_111395.json 에러 발생: name 'date' is not defined
# players_stat_110680.json 에러 발생: name 'date' is not defined
# players_stat_116352.json 에러 발생: name 'date' is not defined
# players_stat_113531.json 에러 발생: name 'date' is not defined
# players_stat_635903.json 에러 발생: name 'date' is not defined
# players_stat_112322.json 에러 발생: name 'date' is not defined
# players_stat_123677.json 에러 발생: name 'date' is not defined
# players_stat_123503.json 에러 발생: name 'date' is not defined
# players_stat_111112.json 에러 발생: name 'date' is not defined
# players_stat_111789.json 에러 발생: name 'date' is not defined
# players_stat_110645.json 에러 발생: name 'date' is not defined
# players_stat_519330.json 에러 발생: name 'date' is not defined
# players_stat_444874.json 에러 발생: name 'date' is not defined
# players_stat_123835.json 에러 발생: name 'date' is not defined
# players_stat_118296.json 에러 발생: name 'date' is not defined
# players_stat_571858.json 에러 발생: name 'date' is not defined
# players_stat_120920.json 에러 발생: name 'date' is not defined
# players_stat_119617.json 에러 발생: name 'date' is not defined
# players_stat_119152.json 에러 발생: name 'date' is not defined
# players_stat_112307.json 에러 발생: name 'date' is not defined
# players_stat_112679.json 에러 발생: name 'date' is not defined
# players_stat_115813.json 에러 발생: name 'date' is not defined
# players_stat_121999.json 에러 발생: name 'date' is not defined
# players_stat_672282.json 에러 발생: name 'date' is not defined
# players_stat_112452.json 에러 발생: name 'date' is not defined
# players_stat_118965.json 에러 발생: name 'date' is not defined
# players_stat_597113.json 에러 발생: name 'date' is not defined
# players_stat_656212.json 에러 발생: name 'date' is not defined
# players_stat_118318.json 에러 발생: name 'date' is not defined
# players_stat_114521.json 에러 발생: name 'date' is not defined
# players_stat_119797.json 에러 발생: name 'date' is not defined
# players_stat_119498.json 에러 발생: name 'date' is not defined
# players_stat_112559.json 에러 발생: name 'date' is not defined
# players_stat_116959.json 에러 발생: name 'date' is not defined
# players_stat_119073.json 에러 발생: name 'date' is not defined
# players_stat_461833.json 에러 발생: name 'date' is not defined
# players_stat_119219.json 에러 발생: name 'date' is not defined
# players_stat_435403.json 에러 발생: name 'date' is not defined
# players_stat_120451.json 에러 발생: name 'date' is not defined
# players_stat_111520.json 에러 발생: name 'date' is not defined
# players_stat_542960.json 에러 발생: name 'date' is not defined
# players_stat_114655.json 에러 발생: name 'date' is not defined
# players_stat_123937.json 에러 발생: name 'date' is not defined
# players_stat_120195.json 에러 발생: name 'date' is not defined
# players_stat_120994.json 에러 발생: name 'date' is not defined
# players_stat_643615.json 에러 발생: name 'date' is not defined
# players_stat_114350.json 에러 발생: name 'date' is not defined
# players_stat_111024.json 에러 발생: name 'date' is not defined
# players_stat_123422.json 에러 발생: name 'date' is not defined
# players_stat_114492.json 에러 발생: name 'date' is not defined
# players_stat_122045.json 에러 발생: name 'date' is not defined
# players_stat_113853.json 에러 발생: name 'date' is not defined
# players_stat_458713.json 에러 발생: name 'date' is not defined
# players_stat_122802.json 에러 발생: name 'date' is not defined
# players_stat_622786.json 에러 발생: name 'date' is not defined
# players_stat_606996.json 에러 발생: name 'date' is not defined
# players_stat_118702.json 에러 발생: name 'date' is not defined
# players_stat_121064.json 에러 발생: name 'date' is not defined
# players_stat_111296.json 에러 발생: name 'date' is not defined
# players_stat_124697.json 에러 발생: name 'date' is not defined
# players_stat_430658.json 에러 발생: name 'date' is not defined
# players_stat_121509.json 에러 발생: name 'date' is not defined
# players_stat_607231.json 에러 발생: name 'date' is not defined
# players_stat_116127.json 에러 발생: name 'date' is not defined
# players_stat_121344.json 에러 발생: name 'date' is not defined
# players_stat_665645.json 에러 발생: name 'date' is not defined
# players_stat_116415.json 에러 발생: name 'date' is not defined
# players_stat_118183.json 에러 발생: name 'date' is not defined
# players_stat_110490.json 에러 발생: name 'date' is not defined
# players_stat_113611.json 에러 발생: name 'date' is not defined
# players_stat_120348.json 에러 발생: name 'date' is not defined
# players_stat_467726.json 에러 발생: name 'date' is not defined
# players_stat_430909.json 에러 발생: name 'date' is not defined
# players_stat_110918.json 에러 발생: name 'date' is not defined
# players_stat_117587.json 에러 발생: name 'date' is not defined
# players_stat_460128.json 에러 발생: name 'date' is not defined
# players_stat_110111.json 에러 발생: name 'date' is not defined
# players_stat_120942.json 에러 발생: name 'date' is not defined
# players_stat_451482.json 에러 발생: name 'date' is not defined
# players_stat_110238.json 에러 발생: name 'date' is not defined
# players_stat_605488.json 에러 발생: name 'date' is not defined
# players_stat_120716.json 에러 발생: name 'date' is not defined
# players_stat_116601.json 에러 발생: name 'date' is not defined
# players_stat_455986.json 에러 발생: name 'date' is not defined
# players_stat_117261.json 에러 발생: name 'date' is not defined
# players_stat_119459.json 에러 발생: name 'date' is not defined
# players_stat_430641.json 에러 발생: name 'date' is not defined
# players_stat_122301.json 에러 발생: name 'date' is not defined
# players_stat_123928.json 에러 발생: name 'date' is not defined
# players_stat_116837.json 에러 발생: name 'date' is not defined
# players_stat_657141.json 에러 발생: name 'date' is not defined
# players_stat_467008.json 에러 발생: name 'date' is not defined
# players_stat_115066.json 에러 발생: name 'date' is not defined
# players_stat_607625.json 에러 발생: name 'date' is not defined
# players_stat_621082.json 에러 발생: name 'date' is not defined
# players_stat_122997.json 에러 발생: name 'date' is not defined
# players_stat_642231.json 에러 발생: name 'date' is not defined
# players_stat_543488.json 에러 발생: name 'date' is not defined
# players_stat_114071.json 에러 발생: name 'date' is not defined
# players_stat_118951.json 에러 발생: name 'date' is not defined
# players_stat_660634.json 에러 발생: name 'date' is not defined
# players_stat_123738.json 에러 발생: name 'date' is not defined
# players_stat_123546.json 에러 발생: name 'date' is not defined
# players_stat_543261.json 에러 발생: name 'date' is not defined
# players_stat_121044.json 에러 발생: name 'date' is not defined
# players_stat_676680.json 에러 발생: name 'date' is not defined
# players_stat_462855.json 에러 발생: name 'date' is not defined
# players_stat_117332.json 에러 발생: name 'date' is not defined
# players_stat_461834.json 에러 발생: name 'date' is not defined
# players_stat_121797.json 에러 발생: name 'date' is not defined
# players_stat_124564.json 에러 발생: name 'date' is not defined
# players_stat_543483.json 에러 발생: name 'date' is not defined
# players_stat_450580.json 에러 발생: name 'date' is not defined
# players_stat_643418.json 에러 발생: name 'date' is not defined
# players_stat_113971.json 에러 발생: name 'date' is not defined
# players_stat_667465.json 에러 발생: name 'date' is not defined
# players_stat_114465.json 에러 발생: name 'date' is not defined
# players_stat_657272.json 에러 발생: name 'date' is not defined
# players_stat_453454.json 에러 발생: name 'date' is not defined
# players_stat_116687.json 에러 발생: name 'date' is not defined
# players_stat_120442.json 에러 발생: name 'date' is not defined
# players_stat_123825.json 에러 발생: name 'date' is not defined
# players_stat_543242.json 에러 발생: name 'date' is not defined
# players_stat_219194.json 에러 발생: name 'date' is not defined
# players_stat_132260.json 에러 발생: name 'date' is not defined
# players_stat_501605.json 에러 발생: name 'date' is not defined
# players_stat_430612.json 에러 발생: name 'date' is not defined
# players_stat_502139.json 에러 발생: name 'date' is not defined
# players_stat_110186.json 에러 발생: name 'date' is not defined
# players_stat_116631.json 에러 발생: name 'date' is not defined
# players_stat_117665.json 에러 발생: name 'date' is not defined
# players_stat_122958.json 에러 발생: name 'date' is not defined
# players_stat_113307.json 에러 발생: name 'date' is not defined
# players_stat_434582.json 에러 발생: name 'date' is not defined
# players_stat_114608.json 에러 발생: name 'date' is not defined
# players_stat_112602.json 에러 발생: name 'date' is not defined
# players_stat_122395.json 에러 발생: name 'date' is not defined
# players_stat_118843.json 에러 발생: name 'date' is not defined
# players_stat_425509.json 에러 발생: name 'date' is not defined
# players_stat_114367.json 에러 발생: name 'date' is not defined
# players_stat_115822.json 에러 발생: name 'date' is not defined
# players_stat_120577.json 에러 발생: name 'date' is not defined
# players_stat_111400.json 에러 발생: name 'date' is not defined
# players_stat_120622.json 에러 발생: name 'date' is not defined
# players_stat_122057.json 에러 발생: name 'date' is not defined
# players_stat_621529.json 에러 발생: name 'date' is not defined
# players_stat_115701.json 에러 발생: name 'date' is not defined
# players_stat_119641.json 에러 발생: name 'date' is not defined
# players_stat_121120.json 에러 발생: name 'date' is not defined
# players_stat_114897.json 에러 발생: name 'date' is not defined
# players_stat_110940.json 에러 발생: name 'date' is not defined
# players_stat_123384.json 에러 발생: name 'date' is not defined
# players_stat_123879.json 에러 발생: name 'date' is not defined
# players_stat_116204.json 에러 발생: name 'date' is not defined
# players_stat_493131.json 에러 발생: name 'date' is not defined
# players_stat_113163.json 에러 발생: name 'date' is not defined
# players_stat_693821.json 에러 발생: name 'date' is not defined
# players_stat_656820.json 에러 발생: name 'date' is not defined
# players_stat_124126.json 에러 발생: name 'date' is not defined
# players_stat_111290.json 에러 발생: name 'date' is not defined
# players_stat_116887.json 에러 발생: name 'date' is not defined
# players_stat_112670.json 에러 발생: name 'date' is not defined
# players_stat_122882.json 에러 발생: name 'date' is not defined
# players_stat_641427.json 에러 발생: name 'date' is not defined
# players_stat_124003.json 에러 발생: name 'date' is not defined
# players_stat_110914.json 에러 발생: name 'date' is not defined
# players_stat_113304.json 에러 발생: name 'date' is not defined
# players_stat_121547.json 에러 발생: name 'date' is not defined
# players_stat_118270.json 에러 발생: name 'date' is not defined
# players_stat_111573.json 에러 발생: name 'date' is not defined
# players_stat_547888.json 에러 발생: name 'date' is not defined
# players_stat_605528.json 에러 발생: name 'date' is not defined
# players_stat_452104.json 에러 발생: name 'date' is not defined
# players_stat_111641.json 에러 발생: name 'date' is not defined
# players_stat_595238.json 에러 발생: name 'date' is not defined
# players_stat_123987.json 에러 발생: name 'date' is not defined
# players_stat_124226.json 에러 발생: name 'date' is not defined
# players_stat_150244.json 에러 발생: name 'date' is not defined
# players_stat_124295.json 에러 발생: name 'date' is not defined
# players_stat_112599.json 에러 발생: name 'date' is not defined
# players_stat_434591.json 에러 발생: name 'date' is not defined
# players_stat_117452.json 에러 발생: name 'date' is not defined
# players_stat_113738.json 에러 발생: name 'date' is not defined
# players_stat_116794.json 에러 발생: name 'date' is not defined
# players_stat_114939.json 에러 발생: name 'date' is not defined
# players_stat_119689.json 에러 발생: name 'date' is not defined
# players_stat_119428.json 에러 발생: name 'date' is not defined
# players_stat_117992.json 에러 발생: name 'date' is not defined
# players_stat_113800.json 에러 발생: name 'date' is not defined
# players_stat_424585.json 에러 발생: name 'date' is not defined
# players_stat_121100.json 에러 발생: name 'date' is not defined
# players_stat_123933.json 에러 발생: name 'date' is not defined
# players_stat_114116.json 에러 발생: name 'date' is not defined
# players_stat_115132.json 에러 발생: name 'date' is not defined
# players_stat_122191.json 에러 발생: name 'date' is not defined
# players_stat_115336.json 에러 발생: name 'date' is not defined
# players_stat_519141.json 에러 발생: name 'date' is not defined
# players_stat_113223.json 에러 발생: name 'date' is not defined
# players_stat_113208.json 에러 발생: name 'date' is not defined
# players_stat_656849.json 에러 발생: name 'date' is not defined
# players_stat_110309.json 에러 발생: name 'date' is not defined
# players_stat_656305.json 에러 발생: name 'date' is not defined
# players_stat_641771.json 에러 발생: name 'date' is not defined
# players_stat_406428.json 에러 발생: name 'date' is not defined
# players_stat_121321.json 에러 발생: name 'date' is not defined
# players_stat_110906.json 에러 발생: name 'date' is not defined
# players_stat_114640.json 에러 발생: name 'date' is not defined
# players_stat_117617.json 에러 발생: name 'date' is not defined
# players_stat_118883.json 에러 발생: name 'date' is not defined
# players_stat_543339.json 에러 발생: name 'date' is not defined
# players_stat_117816.json 에러 발생: name 'date' is not defined
# players_stat_121519.json 에러 발생: name 'date' is not defined
# players_stat_112450.json 에러 발생: name 'date' is not defined
# players_stat_118264.json 에러 발생: name 'date' is not defined
# players_stat_113760.json 에러 발생: name 'date' is not defined
# players_stat_119667.json 에러 발생: name 'date' is not defined
# players_stat_120574.json 에러 발생: name 'date' is not defined
# players_stat_113767.json 에러 발생: name 'date' is not defined
# players_stat_122228.json 에러 발생: name 'date' is not defined
# players_stat_467094.json 에러 발생: name 'date' is not defined
# players_stat_122738.json 에러 발생: name 'date' is not defined
# players_stat_110256.json 에러 발생: name 'date' is not defined
# players_stat_110863.json 에러 발생: name 'date' is not defined
# players_stat_120412.json 에러 발생: name 'date' is not defined
# players_stat_120522.json 에러 발생: name 'date' is not defined
# players_stat_117721.json 에러 발생: name 'date' is not defined
# players_stat_676424.json 에러 발생: name 'date' is not defined
# players_stat_119289.json 에러 발생: name 'date' is not defined
# players_stat_574831.json 에러 발생: name 'date' is not defined
# players_stat_124583.json 에러 발생: name 'date' is not defined
# players_stat_114130.json 에러 발생: name 'date' is not defined
# players_stat_123867.json 에러 발생: name 'date' is not defined
# players_stat_113778.json 에러 발생: name 'date' is not defined
# players_stat_118753.json 에러 발생: name 'date' is not defined
# players_stat_113727.json 에러 발생: name 'date' is not defined
# players_stat_116591.json 에러 발생: name 'date' is not defined
# players_stat_117263.json 에러 발생: name 'date' is not defined
# players_stat_111386.json 에러 발생: name 'date' is not defined
# players_stat_118167.json 에러 발생: name 'date' is not defined
# players_stat_121713.json 에러 발생: name 'date' is not defined
# players_stat_124702.json 에러 발생: name 'date' is not defined
# players_stat_656514.json 에러 발생: name 'date' is not defined
# players_stat_110461.json 에러 발생: name 'date' is not defined
# players_stat_115154.json 에러 발생: name 'date' is not defined
# players_stat_115577.json 에러 발생: name 'date' is not defined
# players_stat_112926.json 에러 발생: name 'date' is not defined
# players_stat_110901.json 에러 발생: name 'date' is not defined
# players_stat_596019.json 에러 발생: name 'date' is not defined
# players_stat_119192.json 에러 발생: name 'date' is not defined
# players_stat_112705.json 에러 발생: name 'date' is not defined
# players_stat_450265.json 에러 발생: name 'date' is not defined
# players_stat_111660.json 에러 발생: name 'date' is not defined
# players_stat_114650.json 에러 발생: name 'date' is not defined
# players_stat_118535.json 에러 발생: name 'date' is not defined
# players_stat_121752.json 에러 발생: name 'date' is not defined
# players_stat_120986.json 에러 발생: name 'date' is not defined
# players_stat_120779.json 에러 발생: name 'date' is not defined
# players_stat_111800.json 에러 발생: name 'date' is not defined
# players_stat_594798.json 에러 발생: name 'date' is not defined
# players_stat_121553.json 에러 발생: name 'date' is not defined
# players_stat_118955.json 에러 발생: name 'date' is not defined
# players_stat_488810.json 에러 발생: name 'date' is not defined
# players_stat_592332.json 에러 발생: name 'date' is not defined
# players_stat_117956.json 에러 발생: name 'date' is not defined
# players_stat_123404.json 에러 발생: name 'date' is not defined
# players_stat_123213.json 에러 발생: name 'date' is not defined
# players_stat_120457.json 에러 발생: name 'date' is not defined
# players_stat_117486.json 에러 발생: name 'date' is not defined
# players_stat_572750.json 에러 발생: name 'date' is not defined
# players_stat_120621.json 에러 발생: name 'date' is not defined
# players_stat_112900.json 에러 발생: name 'date' is not defined
# players_stat_117436.json 에러 발생: name 'date' is not defined
# players_stat_115738.json 에러 발생: name 'date' is not defined
# players_stat_400019.json 에러 발생: name 'date' is not defined
# players_stat_121163.json 에러 발생: name 'date' is not defined
# players_stat_115116.json 에러 발생: name 'date' is not defined
# players_stat_425530.json 에러 발생: name 'date' is not defined
# players_stat_664856.json 에러 발생: name 'date' is not defined
# players_stat_121716.json 에러 발생: name 'date' is not defined
# players_stat_119790.json 에러 발생: name 'date' is not defined
# players_stat_118182.json 에러 발생: name 'date' is not defined
# players_stat_122106.json 에러 발생: name 'date' is not defined
# players_stat_121527.json 에러 발생: name 'date' is not defined
# players_stat_454972.json 에러 발생: name 'date' is not defined
# players_stat_110403.json 에러 발생: name 'date' is not defined
# players_stat_650813.json 에러 발생: name 'date' is not defined
# players_stat_112954.json 에러 발생: name 'date' is not defined
# players_stat_111041.json 에러 발생: name 'date' is not defined
# players_stat_113441.json 에러 발생: name 'date' is not defined
# players_stat_116705.json 에러 발생: name 'date' is not defined
# players_stat_120878.json 에러 발생: name 'date' is not defined
# players_stat_114974.json 에러 발생: name 'date' is not defined
# players_stat_110061.json 에러 발생: name 'date' is not defined
# players_stat_119787.json 에러 발생: name 'date' is not defined
# players_stat_113102.json 에러 발생: name 'date' is not defined
# players_stat_116988.json 에러 발생: name 'date' is not defined
# players_stat_119277.json 에러 발생: name 'date' is not defined
# players_stat_407356.json 에러 발생: name 'date' is not defined
# players_stat_121510.json 에러 발생: name 'date' is not defined
# players_stat_640470.json 에러 발생: name 'date' is not defined
# players_stat_114208.json 에러 발생: name 'date' is not defined
# players_stat_122426.json 에러 발생: name 'date' is not defined
# players_stat_122875.json 에러 발생: name 'date' is not defined
# players_stat_117651.json 에러 발생: name 'date' is not defined
# players_stat_116667.json 에러 발생: name 'date' is not defined
# players_stat_435318.json 에러 발생: name 'date' is not defined
# players_stat_112587.json 에러 발생: name 'date' is not defined
# players_stat_111190.json 에러 발생: name 'date' is not defined
# players_stat_121974.json 에러 발생: name 'date' is not defined
# players_stat_120638.json 에러 발생: name 'date' is not defined
# players_stat_111829.json 에러 발생: name 'date' is not defined
# players_stat_119727.json 에러 발생: name 'date' is not defined
# players_stat_112228.json 에러 발생: name 'date' is not defined
# players_stat_118246.json 에러 발생: name 'date' is not defined
# players_stat_677651.json 에러 발생: name 'date' is not defined
# players_stat_115802.json 에러 발생: name 'date' is not defined
# players_stat_408057.json 에러 발생: name 'date' is not defined
# players_stat_111328.json 에러 발생: name 'date' is not defined
# players_stat_120545.json 에러 발생: name 'date' is not defined
# players_stat_113270.json 에러 발생: name 'date' is not defined
# players_stat_624512.json 에러 발생: name 'date' is not defined
# players_stat_116462.json 에러 발생: name 'date' is not defined
# players_stat_676059.json 에러 발생: name 'date' is not defined
# players_stat_150347.json 에러 발생: name 'date' is not defined
# players_stat_114123.json 에러 발생: name 'date' is not defined
# players_stat_114508.json 에러 발생: name 'date' is not defined
# players_stat_457859.json 에러 발생: name 'date' is not defined
# players_stat_425476.json 에러 발생: name 'date' is not defined
# players_stat_117405.json 에러 발생: name 'date' is not defined
# players_stat_660813.json 에러 발생: name 'date' is not defined
# players_stat_666818.json 에러 발생: name 'date' is not defined
# players_stat_124559.json 에러 발생: name 'date' is not defined
# players_stat_123644.json 에러 발생: name 'date' is not defined
# players_stat_119340.json 에러 발생: name 'date' is not defined
# players_stat_122486.json 에러 발생: name 'date' is not defined
# players_stat_117896.json 에러 발생: name 'date' is not defined
# players_stat_113907.json 에러 발생: name 'date' is not defined
# players_stat_676272.json 에러 발생: name 'date' is not defined
# players_stat_110741.json 에러 발생: name 'date' is not defined
# players_stat_150221.json 에러 발생: name 'date' is not defined
# players_stat_121411.json 에러 발생: name 'date' is not defined
# players_stat_113805.json 에러 발생: name 'date' is not defined
# players_stat_122916.json 에러 발생: name 'date' is not defined
# players_stat_595777.json 에러 발생: name 'date' is not defined
# players_stat_121851.json 에러 발생: name 'date' is not defined
# players_stat_501936.json 에러 발생: name 'date' is not defined
# players_stat_459411.json 에러 발생: name 'date' is not defined
# players_stat_124459.json 에러 발생: name 'date' is not defined
# players_stat_621016.json 에러 발생: name 'date' is not defined
# players_stat_543881.json 에러 발생: name 'date' is not defined
# players_stat_134340.json 에러 발생: name 'date' is not defined
# players_stat_113798.json 에러 발생: name 'date' is not defined
# players_stat_455047.json 에러 발생: name 'date' is not defined
# players_stat_117223.json 에러 발생: name 'date' is not defined
# players_stat_119710.json 에러 발생: name 'date' is not defined
# players_stat_606625.json 에러 발생: name 'date' is not defined
# players_stat_111163.json 에러 발생: name 'date' is not defined
# players_stat_119545.json 에러 발생: name 'date' is not defined
# players_stat_122624.json 에러 발생: name 'date' is not defined
# players_stat_435402.json 에러 발생: name 'date' is not defined
# players_stat_570560.json 에러 발생: name 'date' is not defined
# players_stat_116051.json 에러 발생: name 'date' is not defined
# players_stat_517593.json 에러 발생: name 'date' is not defined
# players_stat_282656.json 에러 발생: name 'date' is not defined
# players_stat_114499.json 에러 발생: name 'date' is not defined
# players_stat_113346.json 에러 발생: name 'date' is not defined
# players_stat_641682.json 에러 발생: name 'date' is not defined
# players_stat_445216.json 에러 발생: name 'date' is not defined
# players_stat_111814.json 에러 발생: name 'date' is not defined
# players_stat_124177.json 에러 발생: name 'date' is not defined
# players_stat_114263.json 에러 발생: name 'date' is not defined
# players_stat_111893.json 에러 발생: name 'date' is not defined
# players_stat_656582.json 에러 발생: name 'date' is not defined
# players_stat_111256.json 에러 발생: name 'date' is not defined
# players_stat_656876.json 에러 발생: name 'date' is not defined
# players_stat_110210.json 에러 발생: name 'date' is not defined
# players_stat_111036.json 에러 발생: name 'date' is not defined
# players_stat_112622.json 에러 발생: name 'date' is not defined
# players_stat_455005.json 에러 발생: name 'date' is not defined
# players_stat_237163.json 에러 발생: name 'date' is not defined
# players_stat_123243.json 에러 발생: name 'date' is not defined
# players_stat_124355.json 에러 발생: name 'date' is not defined
# players_stat_113979.json 에러 발생: name 'date' is not defined
# players_stat_122744.json 에러 발생: name 'date' is not defined
# players_stat_123783.json 에러 발생: name 'date' is not defined
# players_stat_596101.json 에러 발생: name 'date' is not defined
# players_stat_124331.json 에러 발생: name 'date' is not defined
# players_stat_430912.json 에러 발생: name 'date' is not defined
# players_stat_112394.json 에러 발생: name 'date' is not defined
# players_stat_119777.json 에러 발생: name 'date' is not defined
# players_stat_111307.json 에러 발생: name 'date' is not defined
# players_stat_114970.json 에러 발생: name 'date' is not defined
# players_stat_131701.json 에러 발생: name 'date' is not defined
# players_stat_110981.json 에러 발생: name 'date' is not defined
# players_stat_114184.json 에러 발생: name 'date' is not defined
# players_stat_406895.json 에러 발생: name 'date' is not defined
# players_stat_123493.json 에러 발생: name 'date' is not defined
# players_stat_115736.json 에러 발생: name 'date' is not defined
# players_stat_430640.json 에러 발생: name 'date' is not defined
# players_stat_122648.json 에러 발생: name 'date' is not defined
# players_stat_121505.json 에러 발생: name 'date' is not defined
# players_stat_117676.json 에러 발생: name 'date' is not defined
# players_stat_110478.json 에러 발생: name 'date' is not defined
# players_stat_121886.json 에러 발생: name 'date' is not defined
# players_stat_123583.json 에러 발생: name 'date' is not defined
# players_stat_118096.json 에러 발생: name 'date' is not defined
# players_stat_543408.json 에러 발생: name 'date' is not defined
# players_stat_119783.json 에러 발생: name 'date' is not defined
# players_stat_116432.json 에러 발생: name 'date' is not defined
# players_stat_111785.json 에러 발생: name 'date' is not defined
# players_stat_115406.json 에러 발생: name 'date' is not defined
# players_stat_119903.json 에러 발생: name 'date' is not defined
# players_stat_120776.json 에러 발생: name 'date' is not defined
# players_stat_421685.json 에러 발생: name 'date' is not defined
# players_stat_133227.json 에러 발생: name 'date' is not defined
# players_stat_117225.json 에러 발생: name 'date' is not defined
# players_stat_115863.json 에러 발생: name 'date' is not defined
# players_stat_114848.json 에러 발생: name 'date' is not defined
# players_stat_527048.json 에러 발생: name 'date' is not defined
# players_stat_113211.json 에러 발생: name 'date' is not defined
# players_stat_120232.json 에러 발생: name 'date' is not defined
# players_stat_123196.json 에러 발생: name 'date' is not defined
# players_stat_110947.json 에러 발생: name 'date' is not defined
# players_stat_121488.json 에러 발생: name 'date' is not defined
# players_stat_115001.json 에러 발생: name 'date' is not defined
# players_stat_114175.json 에러 발생: name 'date' is not defined
# players_stat_119142.json 에러 발생: name 'date' is not defined
# players_stat_113836.json 에러 발생: name 'date' is not defined
# players_stat_123634.json 에러 발생: name 'date' is not defined
# players_stat_111794.json 에러 발생: name 'date' is not defined
# players_stat_115148.json 에러 발생: name 'date' is not defined
# players_stat_111947.json 에러 발생: name 'date' is not defined
# players_stat_670329.json 에러 발생: name 'date' is not defined
# players_stat_124097.json 에러 발생: name 'date' is not defined
# players_stat_111233.json 에러 발생: name 'date' is not defined
# players_stat_115509.json 에러 발생: name 'date' is not defined
# players_stat_123517.json 에러 발생: name 'date' is not defined
# players_stat_488689.json 에러 발생: name 'date' is not defined
# players_stat_116039.json 에러 발생: name 'date' is not defined
# players_stat_456744.json 에러 발생: name 'date' is not defined
# players_stat_150227.json 에러 발생: name 'date' is not defined
# players_stat_119151.json 에러 발생: name 'date' is not defined
# players_stat_123682.json 에러 발생: name 'date' is not defined
# players_stat_113948.json 에러 발생: name 'date' is not defined
# players_stat_123314.json 에러 발생: name 'date' is not defined
# players_stat_117846.json 에러 발생: name 'date' is not defined
# players_stat_122761.json 에러 발생: name 'date' is not defined
# players_stat_110377.json 에러 발생: name 'date' is not defined
# players_stat_113966.json 에러 발생: name 'date' is not defined
# players_stat_116402.json 에러 발생: name 'date' is not defined
# players_stat_150304.json 에러 발생: name 'date' is not defined
# players_stat_429841.json 에러 발생: name 'date' is not defined
# players_stat_621107.json 에러 발생: name 'date' is not defined
# players_stat_119781.json 에러 발생: name 'date' is not defined
# players_stat_111927.json 에러 발생: name 'date' is not defined
# players_stat_114246.json 에러 발생: name 'date' is not defined
# players_stat_668941.json 에러 발생: name 'date' is not defined
# players_stat_430931.json 에러 발생: name 'date' is not defined
# players_stat_118612.json 에러 발생: name 'date' is not defined
# players_stat_521692.json 에러 발생: name 'date' is not defined
# players_stat_121493.json 에러 발생: name 'date' is not defined
# players_stat_110093.json 에러 발생: name 'date' is not defined
# players_stat_605479.json 에러 발생: name 'date' is not defined
# players_stat_116674.json 에러 발생: name 'date' is not defined
# players_stat_663753.json 에러 발생: name 'date' is not defined
# players_stat_110056.json 에러 발생: name 'date' is not defined
# players_stat_661531.json 에러 발생: name 'date' is not defined
# players_stat_110869.json 에러 발생: name 'date' is not defined
# players_stat_114540.json 에러 발생: name 'date' is not defined
# players_stat_121391.json 에러 발생: name 'date' is not defined
# players_stat_450315.json 에러 발생: name 'date' is not defined
# players_stat_123066.json 에러 발생: name 'date' is not defined
# players_stat_681517.json 에러 발생: name 'date' is not defined
# players_stat_122035.json 에러 발생: name 'date' is not defined
# players_stat_117496.json 에러 발생: name 'date' is not defined
# players_stat_518900.json 에러 발생: name 'date' is not defined
# players_stat_123254.json 에러 발생: name 'date' is not defined
# players_stat_120018.json 에러 발생: name 'date' is not defined
# players_stat_116690.json 에러 발생: name 'date' is not defined
# players_stat_124428.json 에러 발생: name 'date' is not defined
# players_stat_657658.json 에러 발생: name 'date' is not defined
# players_stat_123732.json 에러 발생: name 'date' is not defined
# players_stat_117974.json 에러 발생: name 'date' is not defined
# players_stat_668678.json 에러 발생: name 'date' is not defined
# players_stat_592620.json 에러 발생: name 'date' is not defined
# players_stat_115926.json 에러 발생: name 'date' is not defined
# players_stat_516910.json 에러 발생: name 'date' is not defined
# players_stat_115836.json 에러 발생: name 'date' is not defined
# players_stat_119561.json 에러 발생: name 'date' is not defined
# players_stat_133180.json 에러 발생: name 'date' is not defined
# players_stat_571970.json 에러 발생: name 'date' is not defined
# players_stat_668873.json 에러 발생: name 'date' is not defined
# players_stat_118613.json 에러 발생: name 'date' is not defined
# players_stat_605135.json 에러 발생: name 'date' is not defined
# players_stat_119029.json 에러 발생: name 'date' is not defined
# players_stat_407796.json 에러 발생: name 'date' is not defined
# players_stat_118573.json 에러 발생: name 'date' is not defined
# players_stat_117111.json 에러 발생: name 'date' is not defined
# players_stat_114326.json 에러 발생: name 'date' is not defined
# players_stat_119837.json 에러 발생: name 'date' is not defined
# players_stat_115408.json 에러 발생: name 'date' is not defined
# players_stat_113261.json 에러 발생: name 'date' is not defined
# players_stat_118500.json 에러 발생: name 'date' is not defined
# players_stat_122008.json 에러 발생: name 'date' is not defined
# players_stat_110263.json 에러 발생: name 'date' is not defined
# players_stat_408107.json 에러 발생: name 'date' is not defined
# players_stat_116921.json 에러 발생: name 'date' is not defined
# players_stat_457787.json 에러 발생: name 'date' is not defined
# players_stat_124021.json 에러 발생: name 'date' is not defined
# players_stat_553869.json 에러 발생: name 'date' is not defined
# players_stat_114448.json 에러 발생: name 'date' is not defined
# players_stat_656537.json 에러 발생: name 'date' is not defined
# players_stat_113952.json 에러 발생: name 'date' is not defined
# players_stat_114518.json 에러 발생: name 'date' is not defined
# players_stat_121724.json 에러 발생: name 'date' is not defined
# players_stat_118439.json 에러 발생: name 'date' is not defined
# players_stat_119621.json 에러 발생: name 'date' is not defined
# players_stat_120370.json 에러 발생: name 'date' is not defined
# players_stat_400181.json 에러 발생: name 'date' is not defined
# players_stat_120523.json 에러 발생: name 'date' is not defined
# players_stat_663432.json 에러 발생: name 'date' is not defined
# players_stat_124631.json 에러 발생: name 'date' is not defined
# players_stat_592660.json 에러 발생: name 'date' is not defined
# players_stat_407193.json 에러 발생: name 'date' is not defined
# players_stat_460131.json 에러 발생: name 'date' is not defined
# players_stat_122804.json 에러 발생: name 'date' is not defined
# players_stat_122685.json 에러 발생: name 'date' is not defined
# players_stat_425487.json 에러 발생: name 'date' is not defined
# players_stat_111549.json 에러 발생: name 'date' is not defined
# players_stat_117078.json 에러 발생: name 'date' is not defined
# players_stat_112118.json 에러 발생: name 'date' is not defined
# players_stat_120663.json 에러 발생: name 'date' is not defined
# players_stat_678226.json 에러 발생: name 'date' is not defined
# players_stat_150316.json 에러 발생: name 'date' is not defined
# players_stat_111212.json 에러 발생: name 'date' is not defined
# players_stat_120728.json 에러 발생: name 'date' is not defined
# players_stat_116167.json 에러 발생: name 'date' is not defined
# players_stat_641680.json 에러 발생: name 'date' is not defined
# players_stat_113406.json 에러 발생: name 'date' is not defined
# players_stat_117217.json 에러 발생: name 'date' is not defined
# players_stat_123799.json 에러 발생: name 'date' is not defined
# players_stat_623182.json 에러 발생: name 'date' is not defined
# players_stat_541645.json 에러 발생: name 'date' is not defined
# players_stat_119876.json 에러 발생: name 'date' is not defined
# players_stat_120168.json 에러 발생: name 'date' is not defined
# players_stat_115917.json 에러 발생: name 'date' is not defined
# players_stat_123256.json 에러 발생: name 'date' is not defined
# players_stat_111151.json 에러 발생: name 'date' is not defined
# players_stat_276376.json 에러 발생: name 'date' is not defined
# players_stat_596012.json 에러 발생: name 'date' is not defined
# players_stat_115388.json 에러 발생: name 'date' is not defined
# players_stat_457788.json 에러 발생: name 'date' is not defined
# players_stat_119722.json 에러 발생: name 'date' is not defined
# players_stat_110706.json 에러 발생: name 'date' is not defined
# players_stat_642350.json 에러 발생: name 'date' is not defined
# players_stat_446185.json 에러 발생: name 'date' is not defined
# ...
# players_stat_285063.json 에러 발생: name 'date' is not defined
# players_stat_434480.json 에러 발생: name 'date' is not defined
# players_stat_672820.json 에러 발생: name 'date' is not defined
# players_stat_621383.json 에러 발생: name 'date' is not defined
# players_stat_117909.json 에러 발생: name 'date' is not defined
# players_stat_670955.json 에러 발생: name 'date' is not defined
# players_stat_122188.json 에러 발생: name 'date' is not defined
# players_stat_119028.json 에러 발생: name 'date' is not defined
# players_stat_112081.json 에러 발생: name 'date' is not defined
# players_stat_113887.json 에러 발생: name 'date' is not defined
# players_stat_119045.json 에러 발생: name 'date' is not defined
# players_stat_123405.json 에러 발생: name 'date' is not defined
# players_stat_113671.json 에러 발생: name 'date' is not defined
# players_stat_113999.json 에러 발생: name 'date' is not defined
# players_stat_114745.json 에러 발생: name 'date' is not defined
# players_stat_112807.json 에러 발생: name 'date' is not defined
# players_stat_592612.json 에러 발생: name 'date' is not defined
# players_stat_120882.json 에러 발생: name 'date' is not defined
# players_stat_124402.json 에러 발생: name 'date' is not defined
# players_stat_116429.json 에러 발생: name 'date' is not defined
# players_stat_118225.json 에러 발생: name 'date' is not defined
# players_stat_120561.json 에러 발생: name 'date' is not defined
# players_stat_444876.json 에러 발생: name 'date' is not defined
# players_stat_114303.json 에러 발생: name 'date' is not defined
# players_stat_116856.json 에러 발생: name 'date' is not defined
# players_stat_119533.json 에러 발생: name 'date' is not defined
# players_stat_664167.json 에러 발생: name 'date' is not defined
# players_stat_121057.json 에러 발생: name 'date' is not defined
# players_stat_650907.json 에러 발생: name 'date' is not defined
# players_stat_570615.json 에러 발생: name 'date' is not defined
# players_stat_344924.json 에러 발생: name 'date' is not defined
# players_stat_501647.json 에러 발생: name 'date' is not defined
# players_stat_677020.json 에러 발생: name 'date' is not defined
# players_stat_118422.json 에러 발생: name 'date' is not defined
# players_stat_346857.json 에러 발생: name 'date' is not defined
# players_stat_112209.json 에러 발생: name 'date' is not defined
# players_stat_124028.json 에러 발생: name 'date' is not defined
# players_stat_124758.json 에러 발생: name 'date' is not defined
# players_stat_111585.json 에러 발생: name 'date' is not defined
# players_stat_110653.json 에러 발생: name 'date' is not defined
# players_stat_502130.json 에러 발생: name 'date' is not defined
# players_stat_112760.json 에러 발생: name 'date' is not defined
# players_stat_112201.json 에러 발생: name 'date' is not defined
# players_stat_117040.json 에러 발생: name 'date' is not defined
# players_stat_117797.json 에러 발생: name 'date' is not defined
# players_stat_118293.json 에러 발생: name 'date' is not defined
# players_stat_117964.json 에러 발생: name 'date' is not defined
# players_stat_116111.json 에러 발생: name 'date' is not defined
# players_stat_117412.json 에러 발생: name 'date' is not defined
# players_stat_123889.json 에러 발생: name 'date' is not defined
# players_stat_649144.json 에러 발생: name 'date' is not defined
# players_stat_115050.json 에러 발생: name 'date' is not defined
# players_stat_121803.json 에러 발생: name 'date' is not defined
# players_stat_656290.json 에러 발생: name 'date' is not defined
# players_stat_112934.json 에러 발생: name 'date' is not defined
# players_stat_122119.json 에러 발생: name 'date' is not defined
# players_stat_112287.json 에러 발생: name 'date' is not defined
# players_stat_430907.json 에러 발생: name 'date' is not defined
# players_stat_282333.json 에러 발생: name 'date' is not defined
# players_stat_123100.json 에러 발생: name 'date' is not defined
# players_stat_120515.json 에러 발생: name 'date' is not defined
# players_stat_121310.json 에러 발생: name 'date' is not defined
# players_stat_116504.json 에러 발생: name 'date' is not defined
# players_stat_123074.json 에러 발생: name 'date' is not defined
# players_stat_582473.json 에러 발생: name 'date' is not defined
# players_stat_115070.json 에러 발생: name 'date' is not defined
# players_stat_113442.json 에러 발생: name 'date' is not defined
# players_stat_120126.json 에러 발생: name 'date' is not defined
# players_stat_592274.json 에러 발생: name 'date' is not defined
# players_stat_425503.json 에러 발생: name 'date' is not defined
# players_stat_544365.json 에러 발생: name 'date' is not defined
# players_stat_122449.json 에러 발생: name 'date' is not defined
# players_stat_115138.json 에러 발생: name 'date' is not defined
# players_stat_110121.json 에러 발생: name 'date' is not defined
# players_stat_690829.json 에러 발생: name 'date' is not defined
# players_stat_681882.json 에러 발생: name 'date' is not defined
# players_stat_499624.json 에러 발생: name 'date' is not defined
# players_stat_112920.json 에러 발생: name 'date' is not defined
# players_stat_123064.json 에러 발생: name 'date' is not defined
# players_stat_282882.json 에러 발생: name 'date' is not defined
# players_stat_114871.json 에러 발생: name 'date' is not defined
# players_stat_114405.json 에러 발생: name 'date' is not defined
# players_stat_121530.json 에러 발생: name 'date' is not defined
# players_stat_112382.json 에러 발생: name 'date' is not defined
# players_stat_623430.json 에러 발생: name 'date' is not defined
# players_stat_118136.json 에러 발생: name 'date' is not defined
# players_stat_115638.json 에러 발생: name 'date' is not defined
# players_stat_235194.json 에러 발생: name 'date' is not defined
# players_stat_115281.json 에러 발생: name 'date' is not defined
# players_stat_114341.json 에러 발생: name 'date' is not defined
# players_stat_693304.json 에러 발생: name 'date' is not defined
# players_stat_116376.json 에러 발생: name 'date' is not defined
# players_stat_445222.json 에러 발생: name 'date' is not defined
# players_stat_430618.json 에러 발생: name 'date' is not defined
# players_stat_122373.json 에러 발생: name 'date' is not defined
# players_stat_119406.json 에러 발생: name 'date' is not defined
# players_stat_120298.json 에러 발생: name 'date' is not defined
# players_stat_110805.json 에러 발생: name 'date' is not defined
# players_stat_124532.json 에러 발생: name 'date' is not defined
# players_stat_121885.json 에러 발생: name 'date' is not defined
# players_stat_119275.json 에러 발생: name 'date' is not defined
# players_stat_118699.json 에러 발생: name 'date' is not defined
# players_stat_595005.json 에러 발생: name 'date' is not defined
# players_stat_117885.json 에러 발생: name 'date' is not defined
# players_stat_118492.json 에러 발생: name 'date' is not defined
# players_stat_113200.json 에러 발생: name 'date' is not defined
# players_stat_124042.json 에러 발생: name 'date' is not defined
# players_stat_571863.json 에러 발생: name 'date' is not defined
# players_stat_121683.json 에러 발생: name 'date' is not defined
# players_stat_117096.json 에러 발생: name 'date' is not defined
# players_stat_121508.json 에러 발생: name 'date' is not defined
# players_stat_117626.json 에러 발생: name 'date' is not defined
# players_stat_668674.json 에러 발생: name 'date' is not defined
# players_stat_122465.json 에러 발생: name 'date' is not defined
# players_stat_121322.json 에러 발생: name 'date' is not defined
# players_stat_111333.json 에러 발생: name 'date' is not defined
# players_stat_119187.json 에러 발생: name 'date' is not defined
# players_stat_110313.json 에러 발생: name 'date' is not defined
# players_stat_662139.json 에러 발생: name 'date' is not defined
# players_stat_114872.json 에러 발생: name 'date' is not defined
# players_stat_114307.json 에러 발생: name 'date' is not defined
# players_stat_670087.json 에러 발생: name 'date' is not defined
# players_stat_477557.json 에러 발생: name 'date' is not defined
# players_stat_124263.json 에러 발생: name 'date' is not defined
# players_stat_120410.json 에러 발생: name 'date' is not defined
# players_stat_119356.json 에러 발생: name 'date' is not defined
# players_stat_118048.json 에러 발생: name 'date' is not defined
# players_stat_118146.json 에러 발생: name 'date' is not defined
# players_stat_122554.json 에러 발생: name 'date' is not defined
# players_stat_119725.json 에러 발생: name 'date' is not defined
# players_stat_670623.json 에러 발생: name 'date' is not defined
# players_stat_117065.json 에러 발생: name 'date' is not defined
# players_stat_110950.json 에러 발생: name 'date' is not defined
# players_stat_571868.json 에러 발생: name 'date' is not defined
# players_stat_506555.json 에러 발생: name 'date' is not defined
# players_stat_120302.json 에러 발생: name 'date' is not defined
# players_stat_122484.json 에러 발생: name 'date' is not defined
# players_stat_113548.json 에러 발생: name 'date' is not defined
# players_stat_112943.json 에러 발생: name 'date' is not defined
# players_stat_120691.json 에러 발생: name 'date' is not defined
# players_stat_116381.json 에러 발생: name 'date' is not defined
# players_stat_111557.json 에러 발생: name 'date' is not defined
# players_stat_115457.json 에러 발생: name 'date' is not defined
# players_stat_114963.json 에러 발생: name 'date' is not defined
# players_stat_407797.json 에러 발생: name 'date' is not defined
# players_stat_123355.json 에러 발생: name 'date' is not defined
# players_stat_123564.json 에러 발생: name 'date' is not defined
# players_stat_115472.json 에러 발생: name 'date' is not defined
# players_stat_150142.json 에러 발생: name 'date' is not defined
# players_stat_112434.json 에러 발생: name 'date' is not defined
# players_stat_123228.json 에러 발생: name 'date' is not defined
# players_stat_456133.json 에러 발생: name 'date' is not defined
# players_stat_115648.json 에러 발생: name 'date' is not defined
# players_stat_118217.json 에러 발생: name 'date' is not defined
# players_stat_121951.json 에러 발생: name 'date' is not defined
# players_stat_679032.json 에러 발생: name 'date' is not defined
# players_stat_150135.json 에러 발생: name 'date' is not defined
# players_stat_112026.json 에러 발생: name 'date' is not defined
# players_stat_656731.json 에러 발생: name 'date' is not defined
# players_stat_119195.json 에러 발생: name 'date' is not defined
# players_stat_119315.json 에러 발생: name 'date' is not defined
# players_stat_621259.json 에러 발생: name 'date' is not defined
# players_stat_111162.json 에러 발생: name 'date' is not defined
# players_stat_124639.json 에러 발생: name 'date' is not defined
# players_stat_592127.json 에러 발생: name 'date' is not defined
# players_stat_115121.json 에러 발생: name 'date' is not defined
# players_stat_112054.json 에러 발생: name 'date' is not defined
# players_stat_119766.json 에러 발생: name 'date' is not defined
# players_stat_120056.json 에러 발생: name 'date' is not defined
# players_stat_112739.json 에러 발생: name 'date' is not defined
# players_stat_113326.json 에러 발생: name 'date' is not defined
# players_stat_110764.json 에러 발생: name 'date' is not defined
# players_stat_123949.json 에러 발생: name 'date' is not defined
# players_stat_117963.json 에러 발생: name 'date' is not defined
# players_stat_150102.json 에러 발생: name 'date' is not defined
# players_stat_110014.json 에러 발생: name 'date' is not defined
# players_stat_121062.json 에러 발생: name 'date' is not defined
# players_stat_122559.json 에러 발생: name 'date' is not defined
# players_stat_666128.json 에러 발생: name 'date' is not defined
# players_stat_117808.json 에러 발생: name 'date' is not defined
# players_stat_656024.json 에러 발생: name 'date' is not defined
# players_stat_666310.json 에러 발생: name 'date' is not defined
# players_stat_118470.json 에러 발생: name 'date' is not defined
# players_stat_111458.json 에러 발생: name 'date' is not defined
# players_stat_121443.json 에러 발생: name 'date' is not defined
# players_stat_116032.json 에러 발생: name 'date' is not defined
# players_stat_111618.json 에러 발생: name 'date' is not defined
# players_stat_118798.json 에러 발생: name 'date' is not defined
# players_stat_674370.json 에러 발생: name 'date' is not defined
# players_stat_121086.json 에러 발생: name 'date' is not defined
# players_stat_110048.json 에러 발생: name 'date' is not defined
# players_stat_451775.json 에러 발생: name 'date' is not defined
# players_stat_117650.json 에러 발생: name 'date' is not defined
# players_stat_115019.json 에러 발생: name 'date' is not defined
# players_stat_116901.json 에러 발생: name 'date' is not defined
# players_stat_112236.json 에러 발생: name 'date' is not defined
# players_stat_112813.json 에러 발생: name 'date' is not defined
# players_stat_115401.json 에러 발생: name 'date' is not defined
# players_stat_640454.json 에러 발생: name 'date' is not defined
# players_stat_693049.json 에러 발생: name 'date' is not defined
# players_stat_113479.json 에러 발생: name 'date' is not defined
# players_stat_114197.json 에러 발생: name 'date' is not defined
# players_stat_111409.json 에러 발생: name 'date' is not defined
# players_stat_112249.json 에러 발생: name 'date' is not defined
# players_stat_110615.json 에러 발생: name 'date' is not defined
# players_stat_518617.json 에러 발생: name 'date' is not defined
# players_stat_112823.json 에러 발생: name 'date' is not defined
# players_stat_124398.json 에러 발생: name 'date' is not defined
# players_stat_607706.json 에러 발생: name 'date' is not defined
# players_stat_114134.json 에러 발생: name 'date' is not defined
# players_stat_110727.json 에러 발생: name 'date' is not defined
# players_stat_116079.json 에러 발생: name 'date' is not defined
# players_stat_122181.json 에러 발생: name 'date' is not defined
# players_stat_430899.json 에러 발생: name 'date' is not defined
# players_stat_465015.json 에러 발생: name 'date' is not defined
# players_stat_114302.json 에러 발생: name 'date' is not defined
# players_stat_607162.json 에러 발생: name 'date' is not defined
# players_stat_119197.json 에러 발생: name 'date' is not defined
# players_stat_120706.json 에러 발생: name 'date' is not defined
# players_stat_121221.json 에러 발생: name 'date' is not defined
# players_stat_111342.json 에러 발생: name 'date' is not defined
# players_stat_118357.json 에러 발생: name 'date' is not defined
# players_stat_121708.json 에러 발생: name 'date' is not defined
# players_stat_400127.json 에러 발생: name 'date' is not defined
# players_stat_594867.json 에러 발생: name 'date' is not defined
# players_stat_118286.json 에러 발생: name 'date' is not defined
# players_stat_123931.json 에러 발생: name 'date' is not defined
# players_stat_117306.json 에러 발생: name 'date' is not defined
# players_stat_124762.json 에러 발생: name 'date' is not defined
# players_stat_118769.json 에러 발생: name 'date' is not defined
# players_stat_117470.json 에러 발생: name 'date' is not defined
# players_stat_449777.json 에러 발생: name 'date' is not defined
# players_stat_120050.json 에러 발생: name 'date' is not defined
# players_stat_112451.json 에러 발생: name 'date' is not defined
# players_stat_118984.json 에러 발생: name 'date' is not defined
# players_stat_124701.json 에러 발생: name 'date' is not defined
# players_stat_542953.json 에러 발생: name 'date' is not defined
# players_stat_110734.json 에러 발생: name 'date' is not defined
# players_stat_114010.json 에러 발생: name 'date' is not defined
# players_stat_114229.json 에러 발생: name 'date' is not defined
# players_stat_452737.json 에러 발생: name 'date' is not defined
# players_stat_682016.json 에러 발생: name 'date' is not defined
# players_stat_112064.json 에러 발생: name 'date' is not defined
# players_stat_406954.json 에러 발생: name 'date' is not defined
# players_stat_150211.json 에러 발생: name 'date' is not defined
# players_stat_115253.json 에러 발생: name 'date' is not defined
# players_stat_110964.json 에러 발생: name 'date' is not defined
# players_stat_519345.json 에러 발생: name 'date' is not defined
# players_stat_111848.json 에러 발생: name 'date' is not defined
# players_stat_118308.json 에러 발생: name 'date' is not defined
# players_stat_121154.json 에러 발생: name 'date' is not defined
# players_stat_115197.json 에러 발생: name 'date' is not defined
# players_stat_116023.json 에러 발생: name 'date' is not defined
# players_stat_122656.json 에러 발생: name 'date' is not defined
# players_stat_115970.json 에러 발생: name 'date' is not defined
# players_stat_663898.json 에러 발생: name 'date' is not defined
# players_stat_119758.json 에러 발생: name 'date' is not defined
# players_stat_119901.json 에러 발생: name 'date' is not defined
# players_stat_124505.json 에러 발생: name 'date' is not defined
# players_stat_450855.json 에러 발생: name 'date' is not defined
# players_stat_621563.json 에러 발생: name 'date' is not defined
# players_stat_118070.json 에러 발생: name 'date' is not defined
# players_stat_110977.json 에러 발생: name 'date' is not defined
# players_stat_119971.json 에러 발생: name 'date' is not defined
# players_stat_123371.json 에러 발생: name 'date' is not defined
# players_stat_123333.json 에러 발생: name 'date' is not defined
# players_stat_124116.json 에러 발생: name 'date' is not defined
# players_stat_444447.json 에러 발생: name 'date' is not defined
# players_stat_119200.json 에러 발생: name 'date' is not defined
# players_stat_114771.json 에러 발생: name 'date' is not defined
# players_stat_114742.json 에러 발생: name 'date' is not defined

# %% [markdown]
# # data test

# %%
# MariaDB 연결
connection = mysql.connector.connect(**config)

# SQL 쿼리 실행
cursor = connection.cursor()
cursor.execute('select * from player;')

players = cursor.fetchall()
# 테이블 목록 출력
print(len(players))
for player in players:
    print(player)

# 연결 종료
cursor.close()
connection.close()
# Out:
# 0

# %%
from pyspark.sql import SparkSession

# SparkSession을 생성합니다.
spark = SparkSession.builder \
    .appName("JSONtoMariaDB") \
    .getOrCreate()

# %%
# MariaDB 연결 정보 설정
jdbc_url = "jdbc:mariadb://your_db_host:your_db_port/your_db_name"
properties = {
    "user": "your_db_user",
    "password": "your_db_password",
    "driver": "org.mariadb.jdbc.Driver"
}

# %%
# JSON 데이터를 읽어옵니다. 예시 파일 경로를 수정하세요.
json_data = spark.read.json("path/to/your/json/data.json")
json_data = json_data.withColumnRenamed("key_name", "new_column_name")

# DataFrame을 MariaDB 테이블에 저장
json_data.write.jdbc(url=jdbc_url, table="your_table_name", mode="overwrite", properties=properties)

spark.stop()
